# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline 
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report , accuracy_score
import numpy as np

# %%
df =pd.read_csv("insurance_data.csv")

# %%
df.sample(5)
# Out:
#     age  weight  height  income_lpa smoker        city       occupation  \
# 7    41      77     175        15.0     No     Kolkata     Bank Manager
# 12   52      92     180        25.0    Yes  Chandigarh    Industrialist
# 1    32      75     172        12.0    Yes      Mumbai    Sales Manager
# 15   44      80     176        16.5    Yes       Surat  Operations Head
# 4    38      90     178        22.0    Yes        Pune       Consultant
#
#    insurance_premium_category
# 7                      Medium
# 12                       High
# 1                        High
# 15                       High
# 4                        High

# %%
#will apply feature engineering so create copy of data set 
df_feat=df.copy()

# %%
#FEATURE 1 :BMI
df_feat["bmi"]=df_feat["weight"]/(df_feat["height"]**2)

# %%
#FEATURE 2:AGE GROUP
def age_group(age):
    if age<25:
        return "young"
    elif age<45:
        return "adult"
    elif age<60:
        return "middle_aged"
    return "senior"

# %%
df_feat["age_group"]=df_feat["age"].apply(age_group)

# %%
 #FEATURE 3 LIFESTYLE
def life_style_risk(row):
    if row["smoker"] and row["bmi"]>30:
        return "high"
    elif row["smoker"] or row["bmi"]>27:
        return "medium"
    else:
        return "low"
#Haan, bilkul! Jab aapko ek se zyada columns (yaani pure row) ka data use
# karke koi naya feature nikalna hota hai, toh Pandas mein yahi standard tareeka
# hai.

# %%
df_feat["lifestyle_risk"] = df_feat.apply(life_style_risk , axis=1)

# %%
df["city"]
# Out:
# 0          Delhi
# 1         Mumbai
# 2      Bangalore
# 3      Hyderabad
# 4           Pune
# 5        Chennai
# 6         Jaipur
# 7        Kolkata
# 8      Ahmedabad
# 9          Noida
# 10       Gurgaon
# 11       Lucknow
# 12    Chandigarh
# 13        Indore
# 14        Bhopal
# 15         Surat
# 16        Nagpur
# 17         Patna
# 18    Coimbatore
# 19        Ranchi
# Name: city, dtype: str

# %%
tier_1=["Delhi" ,"Mumbai"," Bangalore"," Hyderabad"," Pune"," Chennai"]
tier_2=["Ranchi","Kolkata","Surat"]

# %%
#FEATURE 4:CITY_TIER
def city_tier(city):
    if city in tier_1:
        return 1
    elif city in tier_2:
        return 2
    else:
        return 3

# %%
df_feat["city_tier"]=df_feat["city"].apply(city_tier)

# %%
df_feat.drop(columns=["age","weight","height","smoker","city"])
# Out:
#     income_lpa           occupation insurance_premium_category       BMI  \
# 0          6.5    Software Engineer                        Low  0.002204
# 1         12.0        Sales Manager                       High  0.002535
# 2         18.5       Business Owner                     Medium  0.002905
# 3          8.2              Teacher                        Low  0.002353
# 4         22.0           Consultant                       High  0.002841
# 5         10.5               Driver                       High  0.003320
# 6          5.8     Graphic Designer                        Low  0.002096
# 7         15.0         Bank Manager                     Medium  0.002514
# 8          9.5  Marketing Executive                     Medium  0.002416
# 9         11.2         Data Analyst                        Low  0.002462
# 10        20.0         Entrepreneur                       High  0.002907
# 11         7.5           HR Manager                        Low  0.002295
# 12        25.0        Industrialist                       High  0.002840
# 13        13.0      Project Manager                     Medium  0.002339
# 14         6.0       Content Writer                        Low  0.002156
# 15        16.5      Operations Head                       High  0.002583
# 16         9.0           Accountant                        Low  0.002338
# 17        19.0           Contractor                       High  0.002839
# 18        10.0            Professor                     Medium  0.002526
# 19         5.5     Junior Developer                        Low  0.002221
#
#       age_group       bmi lifestyle_risk  city_tier
# 0         adult  0.002204         medium          1
# 1         adult  0.002535         medium          1
# 2   middle_aged  0.002905         medium          3
# 3         adult  0.002353         medium          3
# 4         adult  0.002841         medium          3
# 5   middle_aged  0.003320         medium          3
# 6         adult  0.002096         medium          3
# 7         adult  0.002514         medium          2
# 8         adult  0.002416         medium          3
# 9         adult  0.002462         medium          3
# 10  middle_aged  0.002907         medium          3
# 11        adult  0.002295         medium          3
# 12  middle_aged  0.002840         medium          3
# 13        adult  0.002339         medium          3
# 14        adult  0.002156         medium          3
# 15        adult  0.002583         medium          2
# 16        adult  0.002338         medium          3
# 17  middle_aged  0.002839         medium          3
# 18        adult  0.002526         medium          3
# 19        adult  0.002221         medium          2

# %%
#select features and target
x=df_feat[["bmi","age_group","lifestyle_risk","city_tier","income_lpa","occupation"]]
y=df_feat["insurance_premium_category"]

# %%
x
# Out:
#          bmi    age_group lifestyle_risk  city_tier  income_lpa  \
# 0   0.002204        adult         medium          1         6.5
# 1   0.002535        adult         medium          1        12.0
# 2   0.002905  middle_aged         medium          3        18.5
# 3   0.002353        adult         medium          3         8.2
# 4   0.002841        adult         medium          3        22.0
# 5   0.003320  middle_aged         medium          3        10.5
# 6   0.002096        adult         medium          3         5.8
# 7   0.002514        adult         medium          2        15.0
# 8   0.002416        adult         medium          3         9.5
# 9   0.002462        adult         medium          3        11.2
# 10  0.002907  middle_aged         medium          3        20.0
# 11  0.002295        adult         medium          3         7.5
# 12  0.002840  middle_aged         medium          3        25.0
# 13  0.002339        adult         medium          3        13.0
# 14  0.002156        adult         medium          3         6.0
# 15  0.002583        adult         medium          2        16.5
# 16  0.002338        adult         medium          3         9.0
# 17  0.002839  middle_aged         medium          3        19.0
# 18  0.002526        adult         medium          3        10.0
# 19  0.002221        adult         medium          2         5.5
#
#              occupation
# 0     Software Engineer
# 1         Sales Manager
# 2        Business Owner
# 3               Teacher
# 4            Consultant
# 5                Driver
# 6      Graphic Designer
# 7          Bank Manager
# 8   Marketing Executive
# 9          Data Analyst
# 10         Entrepreneur
# 11           HR Manager
# 12        Industrialist
# 13      Project Manager
# 14       Content Writer
# 15      Operations Head
# 16           Accountant
# 17           Contractor
# 18            Professor
# 19     Junior Developer

# %%
y
# Out:
# 0        Low
# 1       High
# 2     Medium
# 3        Low
# 4       High
# 5       High
# 6        Low
# 7     Medium
# 8     Medium
# 9        Low
# 10      High
# 11       Low
# 12      High
# 13    Medium
# 14       Low
# 15      High
# 16       Low
# 17      High
# 18    Medium
# 19       Low
# Name: insurance_premium_category, dtype: str

# %%
#categorial_features and numeric features
categorical_features=["age_group","lifestyle_risk","city_tier","occupation"]
numeric_features=["bmi","income_lpa"]

# %%
#Create column transformer for OHE
preprocessor =ColumnTransformer(
    transformers=[
        ("cat",OneHotEncoder(handle_unknown='ignore'),categorical_features),
        ("num","passthrough",numeric_features)
    ]
)

# %%
#Create a pipleline with preprocessing and random forest classifier
pipeline=Pipeline(steps=[
    ("preprocessor" , preprocessor),
    ("classifier",RandomForestClassifier(random_state=42))
])

# %%
#split data and train model
x_train , x_test ,y_train , y_test=train_test_split(x,y,test_size=0.2,random_state=1)
pipeline.fit(x_train , y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['age_group',
#                                                    'lifestyle_risk',
#                                                    'city_tier', 'occupation']),
#                                                  ('num', 'passthrough',
#                                                   ['bmi', 'income_lpa'])])),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
#split and train model

y_pred = pipeline.predict(x_test)
accuracy_score(y_test ,y_pred)
# Out:
# 0.75

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 x_test.sample(5)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:6000, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5997 if weights is not None:
#    5998     weights = sample.preprocess_weights(self, weights, axis)
# -> 6000 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6001 result = self.take(sampled_indices, axis=axis)
#    6003 if ignore_index:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\sample.py:161, in sample(obj_len, size, replace, weights, random_state)
#     154     if not replace and size * weights.max() > 1:
#     155         raise ValueError(
#     156             "Weighted sampling cannot be achieved with replace=False. Either "
#     157             "set replace=True or use smaller weights. See the docstring of "
#     158             "sample for details."
#     159         )
# --> 161 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     162     np.intp, copy=False
#     163 )
#
# File numpy/random/mtrand.pyx:1020, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'
